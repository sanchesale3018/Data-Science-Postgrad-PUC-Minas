# %%
import pandas as pd

# %%
dataset=pd.read_excel("dataset.xlsx")
dataset
# Out:
#                                                Texto
# 0  Este produto é excelente, superou minhas expec...
# 1         Achei muito ruim, não compraria novamente.
# 2          O atendimento foi mediano, nada especial.
# 3            Estou muito satisfeito com a qualidade.
# 4      Estou muito pouco satisfeito com a qualidade.
# 5    Terrível experiência, totalmente decepcionante!
# 6           A camisa é excelente, muito confortável.
# 7                      O Windows 11 não é muito bom.

# %%
from transformers import pipeline as pip

# %%
analisador = pip("sentiment-analysis", model = "nlptown/bert-base-multilingual-uncased-sentiment", framework = "pt")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 analisador = pip("sentiment-analysis", model = "nlptown/bert-base-multilingual-uncased-sentiment", framework = "pt")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\pipelines\__init__.py:1027, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, video_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1022         raise ValueError(
#    1023             'You cannot use both `pipeline(... dtype=..., model_kwargs={"dtype":...})` as those'
#    1024             " arguments might conflict, use only one.)"
#    1025         )
#    1026 if dtype is not None:
# -> 1027     if isinstance(dtype, str) and hasattr(torch, dtype):
# ...
